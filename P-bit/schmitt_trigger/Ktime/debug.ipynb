# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
sd = np.linspace(0.4, 0.9, 10)
Ktime_0_2 = [0.003028837, 0.0019012685, 0.0016393932, 0.0015495734, 0.0013922559, 0.0010379846, 0.0006103293, 0.0007317618, 0.00046972954, 0.00055609684]
Ktime_0_1 = [0.008204392, 0.0040662824, 0.0022077528, 0.0020707208, 0.0013701424, 0.0010068769, 0.0010516273, 0.00063497777, 0.00060374214, 0.00053554925]
Ktime_0_05 = [0.008683408, 0.0036179281, 0.0025093914, 0.0012966419, 0.0013434659, 0.0012035823, 0.00080366695, 0.0009444305, 0.0009700531, 0.00069775374]
plt.plot(sd, Ktime_0_2, '--s')
plt.plot(sd, Ktime_0_1, '--s')
plt.plot(sd, Ktime_0_05, '--s')

# %%
sd = np.linspace(0.4, 0.8, 10)
Ktime_0_1 =  [0.008733186, 0.0041547874, 0.0027017598, 0.0022576635, 0.0017981991, 0.0015009248, 0.0012726488, 0.00081797125, 0.0009775609, 0.0008251436]
Ktime_0_1_1 =  np.array([0.0054364624, 0.005004103, 0.0030625337, 0.0020749096, 0.0017109285, 0.0012283749, 0.0014361319, 0.0010785983, 0.00075674703, 0.000616202])
Ktime_0_1_2 =  np.array([0.0050698877, 0.0046214093, 0.0028787956, 0.0023434642, 0.0014810174, 0.0013486273, 0.00087261084, 0.0009968942, 0.00083912286, 0.0009499076])
Ktime_0_1_3 =  np.array([0.0059092226, 0.004759642, 0.0037693502, 0.002109178, 0.0017167242, 0.0014234849, 0.0009595087, 0.0010721614, 0.0007366906, 0.00075086544])

# plt.plot(sd, Ktime_0_1, '--s')
plt.plot(sd, Ktime_0_1_1, '--s')
plt.plot(sd, Ktime_0_1_2, '--s')
plt.plot(sd, Ktime_0_1_3, '--s')
plt.plot(sd, (Ktime_0_1_3 + Ktime_0_1_2 + Ktime_0_1_1)/3, '--s')

# %%
sd = np.linspace(0.4, 0.8, 10)

Ktime_0_1 =  np.array([0.006313631683588028, 0.0038375654257833958, 0.0026635766495019197, 0.0021029910654760896, 0.0017472141073085368, 0.0014045057236216963, 0.0011440951377153397, 0.0009716696513351053, 0.0008567584212869406, 0.0007735137827694416])
Ktime_0_15 =  np.array([0.004932968597859144, 0.0033030119491741063, 0.0023404817446134986, 0.0018578311195597053, 0.0015394445043057203, 0.0012485250947065652, 0.0009700158727355302, 0.0008755681104958057, 0.0008072378172073513, 0.0007261433231178672])
Ktime_0_2 =  np.array([0.003741038450971246, 0.0029900400899350644, 0.002302542398683727, 0.0017794426181353628, 0.0014354584622196854, 0.0012689976370893418, 0.0009740249486640095, 0.0007904974394477904, 0.0007239090860821307, 0.0006637307291384786])

plt.plot(sd, Ktime_0_1*1e3, '--s', label = "0.1 V bias", c = "blue")
plt.plot(sd, Ktime_0_15*1e3, '--s', label = "0.15 V bias", c = "black")
plt.plot(sd, Ktime_0_2*1e3, '--s', label = "0.2 V bias", c = "red")

plt.xlabel("s.d")
plt.ylabel("K-time (ms)")
plt.legend()
plt.grid()

# %%
sd = np.linspace(0.35, 0.8, 11)

Ktime_0_1 =  np.array([0.014288312522694468, 0.006313631683588028, 0.0038375654257833958, 0.0026635766495019197, 0.0021029910654760896, 0.0017472141073085368, 0.0014045057236216963, 0.0011440951377153397, 0.0009716696513351053, 0.0008567584212869406, 0.0007735137827694416])
Ktime_0_15 =  np.array([0.014939190167933703, 0.004932968597859144, 0.0033030119491741063, 0.0023404817446134986, 0.0018578311195597053, 0.0015394445043057203, 0.0012485250947065652, 0.0009700158727355302, 0.0008755681104958057, 0.0008072378172073513, 0.0007261433231178672])
Ktime_0_2 =  np.array([0.012066809134557844, 0.003741038450971246, 0.0029900400899350644, 0.002302542398683727, 0.0017794426181353628, 0.0014354584622196854, 0.0012689976370893418, 0.0009740249486640095, 0.0007904974394477904, 0.0007239090860821307, 0.0006637307291384786])

plt.plot(sd, Ktime_0_1*1e3, '--s', label = "0.1 V bias")
plt.plot(sd, Ktime_0_15*1e3, '--s', label = "0.15 V bias")
plt.plot(sd, Ktime_0_2*1e3, '--s', label = "0.2 V bias")

plt.xlabel("s.d")
plt.ylabel("time (ms)")
plt.legend()
plt.grid()
